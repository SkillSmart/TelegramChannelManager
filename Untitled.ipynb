# %%
import pandas as pd

# %%
df = pd.read_csv("DREAM Token_userlist.csv")
df
# Out:
#              id                                         first_name  \
# 0     470543246                                                  j
# 1     573271937                                            Margery
# 2     424815611                                             seojin
# 3     526665821                                                 智超
# 4     551059574                                                 hh
# 5     551820414                                                  m
# 6     523161896                                           zhunluan
# 7     608431384                                                wDf
# 8     615670637                                              Tyler
# 9     458188648                                            Porsche
# 10    539850428                                             Martha
# 11    592807911                                                  j
# 12    414882043                                                iYd
# ...

# %%
# Work with individual cols
cols = ['id', 'first_name', 'last_name']
df[cols].count()
# Out:
# id            10000
# first_name     9993
# last_name      9139
# dtype: int64

# %%
df['id'].head()
# Out:
# 0    470543246
# 1    573271937
# 2    424815611
# 3    526665821
# 4    551059574
# Name: id, dtype: int64

# %%
df['id'].tail()
# Out:
# 9995    613740778
# 9996    614173768
# 9997    614713610
# 9998    619513099
# 9999    385234193
# Name: id, dtype: int64

# %%
df.keys()
# Out:
# Index(['id', 'first_name', 'last_name', 'username', 'phone', 'lang', 'is_self',
#        'contact', 'mutual_contact', 'deleted', 'bot', 'bot_chat_history',
#        'bot_nochats', 'verified', 'restricted', 'min', 'bot_inline_geo',
#        'access_hash', 'is_online', 'recently_online', 'is_offline',
#        'last_online', 'bot_info_version', 'restriction_reason',
#        'bot_inline_placeholder'],
#       dtype='object')

# %%
df_2 = df

# %%
joined_df = df.join(df_2, "id", lsuffix="_2")
joined_df
# Out:
#            id_2                                       first_name_2  \
# 0     470543246                                                  j
# 1     573271937                                            Margery
# 2     424815611                                             seojin
# 3     526665821                                                 智超
# 4     551059574                                                 hh
# 5     551820414                                                  m
# 6     523161896                                           zhunluan
# 7     608431384                                                wDf
# 8     615670637                                              Tyler
# 9     458188648                                            Porsche
# 10    539850428                                             Martha
# 11    592807911                                                  j
# 12    414882043                                                iYd
# ...
